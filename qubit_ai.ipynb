# %% [markdown]
# <a href="https://colab.research.google.com/github/tapiocaTakeshi/Qubit/blob/main/qubit_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Cloning the GitHub Repository
#
# I will now clone the provided GitHub repository using `git clone`.

# %% [markdown]
# ### Pushing Changes to GitHub
#
# To push your changes to a GitHub repository, you will typically use the following sequence of Git commands. Ensure you have committed your changes before pushing.

# %%
repo_url = 'https://github.com/tapiocaTakeshi/Qubit.git'
# !git clone {repo_url}

# %% [markdown]
# ### Installing Dependencies
#
# Now, I will install the required Python packages from the `requirements.txt` file located in the cloned `Qubit` repository.

# %%
# %cd Qubit
# !pip install -r requirements.txt

# %%
# !pip install datasets

# %%
# !python train_hf_dataset.py \
  --dataset-id wikimedia/wikipedia \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id google/wiki40b \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id allenai/c4 \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id mc4 \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id Open-Orca/OpenOrca \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id HuggingFaceH4/ultrachat_200k \
  --split train_sft \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id open-thoughts/OpenThoughts-114k \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id argilla/ultrafeedback-binarized-preferences \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id bigcode/the-stack-v2 \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id ise-uiuc/Magicoder-OSS-Instruct-75K \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id WizardLMTeam/WizardCoder-Python-34K \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id HuggingFaceH4/CodeAlpaca_20K \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id meta-math/MetaMathQA \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id AI-MO/NuminaMath-CoT \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# !python train_hf_dataset.py \
  --dataset-id gsm8k \
  --config-name main \
  --split train \
  --epochs 3 \
  --batch-size 1 \
  --ckpt-name ./models/qbnn_combined_checkpoint.pt \
  --resume

# %%
# First, navigate to your repository directory if you are not already there
# %cd /content/Qubit

# Add all changes to the staging area
# !git add .

# Commit the changes with a message
# !git commit -m "Update notebook with latest changes"

# Push the changes to the remote repository (e.g., 'origin' and 'main' branch)
# !git push origin main
